# %%
#!/usr/bin/env python
# coding: utf-8

# Deep Deterministic Policy Gradient for Portfolio Management
#  
# 1. We have already overfit the model by training on 16 stocks using 3 years of training data 
# Training was done by running stock_traindg.py using DDPG lstm 3 steps window on these 16 stocks
# ['AAPL', 'ATVI', 'CMCSA', 'COST', 'CSX', 'DISH', 'EA', 'EBAY', 'FB', 'GOOGL', 'HAS', 'ILMN', 'INTC', 'MAR', 'REGN', 'SBUX']
#
# 2. We then load a second dataset with different 16 stocks OHLC data
# 3. We test the model performance on the new stocks data (not seen during training) for the training time period
# 4. We then test the model performance on the new stocks data for the testing time period (neither was seen during training)

# %%
import os
#os.chdir('/mnt/c/c/Users/byacoube/source/repos/capstone/src')
#os.chdir(r'C:\Users\byacoube\source\repos\capstone\src')
#from google.colab import drive
#drive.mount('/content/drive')
os.environ["KERAS_BACKEND"] = "theano"
import numpy as np
from utils.data import read_stock_history, index_to_date, date_to_index, normalize
import matplotlib.pyplot as plt
import matplotlib
# for compatible with python 3
#from __future__ import print_function
get_ipython().run_line_magic('matplotlib', 'inline')
get_ipython().run_line_magic('load_ext', 'autoreload')
get_ipython().run_line_magic('autoreload', '2')

# %%
# Seaborn, useful for graphics
import seaborn as sns

# Import Bokeh modules for interactive plotting
import bokeh.io
#import bokeh.mpl
import bokeh.plotting

# Magic function to make matplotlib inline; other style specs must come AFTER
get_ipython().run_line_magic('matplotlib', 'inline')

# This enables SVG graphics inline.  There is a bug, so uncomment if it works.
# %config InlineBackend.figure_formats = {'svg',}

# This enables high resolution PNGs. SVG is preferred, but has problems
# rendering vertical and horizontal lines
get_ipython().run_line_magic('config', "InlineBackend.figure_formats = {'png', 'retina'}")
matplotlib.rcParams['figure.figsize'] = (10, 6)
plt.rc('legend', fontsize=20)
# configure Seaborn settings 
rc = {'lines.linewidth': 2, 
      'axes.labelsize': 18, 
      'axes.titlesize': 18, 
      'axes.facecolor': 'EFEFD5'}
sns.set_context('notebook', rc=rc)
sns.set_style('darkgrid', rc=rc)

# Set up Bokeh for inline viewing
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a176610b-e94f-4ba4-b3a1-354a73299363">Loading BokehJS ...</span>
#     </div>

# %%
# read the data and choose the target stocks for training a toy example
history, abbreviation = read_stock_history(filepath='utils/datasets/stocks_history_target.h5')
history = history[:, :, :4]
num_training_time = history.shape[1]
num_testing_time = history.shape[1]
window_length = 30

# %%
history.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25220/3024368664.py in <module>
# ----> 1 history.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
# dataset for 16 stocks by splitting timestamp
history, abbreviation = read_stock_history(filepath='utils/datasets/stocks_history_target.h5')
history = history[:, :, :4]

# 16 stocks are all involved. We choose first 3 years as training data
num_training_time = 1095
target_stocks = abbreviation
target_history = np.empty(shape=(len(target_stocks), num_training_time, history.shape[2]))

for i, stock in enumerate(target_stocks):
    target_history[i] = history[abbreviation.index(stock), :num_training_time, :]

# and last 2 years as testing data.
testing_stocks = abbreviation
testing_history = np.empty(shape=(len(testing_stocks), history.shape[1] - num_training_time, 
                               history.shape[2]))
for i, stock in enumerate(testing_stocks):
    testing_history[i] = history[abbreviation.index(stock), num_training_time:, :]
print( abbreviation)
print("target_history.shape stocks, steps, OHLC", target_history.shape)
print("testing_history.shape stocks, steps, OHLC", testing_history.shape)
# Out:
# ['AAPL', 'ATVI', 'CMCSA', 'COST', 'CSX', 'DISH', 'EA', 'EBAY', 'FB', 'GOOGL', 'HAS', 'ILMN', 'INTC', 'MAR', 'REGN', 'SBUX']
# target_history.shape stocks, steps, OHLC (16, 1095, 4)
# testing_history.shape stocks, steps, OHLC (16, 730, 4)

# %%
nb_classes = len(target_stocks) + 1

# visualize stock prices
if True:
    date_list = [index_to_date(i) for i in range(target_history.shape[1])]
    x = range(target_history.shape[1])
    for i in range(len(target_stocks)):
        plt.figure(i)
        plt.plot(x, target_history[i, :, 1])  # open, high, low, close = [0, 1, 2, 3]
        plt.xticks(x[::200], date_list[::200], rotation=30)
        plt.title(target_stocks[i])
        plt.show()

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

from model.ddpg.actor import ActorNetwork
from model.ddpg.critic import CriticNetwork
from model.ddpg.ddpg import DDPG
from model.ddpg.ornstein_uhlenbeck import OrnsteinUhlenbeckActionNoise

import numpy as np
import tflearn

from stock_trading import StockActor, StockCritic, obs_normalizer, multi_feature_obs_normalizer, get_model_path, get_result_path,test_model, get_variable_scope, test_model_multiple
    
from model.supervised.lstm import StockLSTM
from model.supervised.cnn import StockCNN
tf.__version__
# Out:
# WARNING:tensorflow:From c:\users\mithu\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# curses is not supported on this machine (please install/reinstall curses for an optimal experience)
# '2.12.0'

# %%
# common settings
batch_size = 64
action_bound = 1.
tau = 1e-3

models = []
model_names = []
window_length_lst = [3]
predictor_type_lst = ['transformer']
use_batch_norm = True


# instantiate environment, 16 stocks, with trading cost, window_length 3, start_date sample each time
for window_length in window_length_lst:
    for predictor_type in predictor_type_lst:
        name = 'DDPG_window_{}_predictor_{}'.format(window_length, predictor_type)
        model_names.append(name)
        tf.reset_default_graph()
        sess = tf.Session()
        tflearn.config.init_training_mode()
        action_dim = [nb_classes]
        state_dim = [nb_classes, window_length]
        variable_scope = get_variable_scope(window_length, predictor_type, use_batch_norm)
        with tf.variable_scope(variable_scope):
            actor = StockActor(sess, state_dim, action_dim, action_bound, 1e-4, tau, batch_size, predictor_type, 
                               use_batch_norm)
            critic = StockCritic(sess=sess, state_dim=state_dim, action_dim=action_dim, tau=1e-3,
                                 learning_rate=1e-3, num_actor_vars=actor.get_num_trainable_vars(), 
                                 predictor_type=predictor_type, use_batch_norm=use_batch_norm)
            actor_noise = OrnsteinUhlenbeckActionNoise(mu=np.zeros(action_dim))

            model_save_path = get_model_path(window_length, predictor_type, use_batch_norm)
            summary_path = get_result_path(window_length, predictor_type, use_batch_norm)

            ddpg_model = DDPG(None, sess, actor, critic, actor_noise, obs_normalizer=multi_feature_obs_normalizer,
                              config_file='config/stock.json', model_save_path=model_save_path,
                              summary_path=summary_path)
            ddpg_model.initialize(load_weights=True, verbose=True)
            models.append(ddpg_model)
# Out:
# Reshaped input: (?, 17, 3)
# After reshape: (?, 17, 3)
# Output: (?, 544)
# Reshaped input: (?, 17, 3)
# After reshape: (?, 17, 3)
# Output: (?, 544)
# Reshaped input: (?, 17, 3)
# After reshape: (?, 17, 3)
# Output: (?, 544)
# Reshaped input: (?, 17, 3)
# After reshape: (?, 17, 3)
# Output: (?, 544)
# INFO:tensorflow:Restoring parameters from weights/stock/transformer/window_3/batch_norm/checkpoint.ckpt
# Loading is_training:0 from checkpoint. Name: is_training
# Loading transformer_window_3_batch_norm/FullyConnected/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected/W
# Loading transformer_window_3_batch_norm/FullyConnected/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected/b
# Loading transformer_window_3_batch_norm/FullyConnected_1/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_1/W
# Loading transformer_window_3_batch_norm/FullyConnected_1/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_1/b
# Loading transformer_window_3_batch_norm/FullyConnected_2/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_2/W
# Loading transformer_window_3_batch_norm/FullyConnected_2/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_2/b
# Loading transformer_window_3_batch_norm/FullyConnected_3/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_3/W
# Loading transformer_window_3_batch_norm/FullyConnected_3/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_3/b
# Loading transformer_window_3_batch_norm/BatchNormalization/beta:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization/beta
# Loading transformer_window_3_batch_norm/BatchNormalization/gamma:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization/gamma
# Loading transformer_window_3_batch_norm/BatchNormalization/moving_mean:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization/moving_mean
# Loading transformer_window_3_batch_norm/BatchNormalization/moving_variance:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization/moving_variance
# Loading transformer_window_3_batch_norm/FullyConnected_4/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_4/W
# Loading transformer_window_3_batch_norm/FullyConnected_4/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_4/b
# Loading transformer_window_3_batch_norm/FullyConnected_5/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_5/W
# Loading transformer_window_3_batch_norm/FullyConnected_5/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_5/b
# Loading transformer_window_3_batch_norm/BatchNormalization_1/beta:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_1/beta
# Loading transformer_window_3_batch_norm/BatchNormalization_1/gamma:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_1/gamma
# Loading transformer_window_3_batch_norm/BatchNormalization_1/moving_mean:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_1/moving_mean
# Loading transformer_window_3_batch_norm/BatchNormalization_1/moving_variance:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_1/moving_variance
# Loading transformer_window_3_batch_norm/FullyConnected_6/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_6/W
# Loading transformer_window_3_batch_norm/FullyConnected_6/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_6/b
# Loading transformer_window_3_batch_norm/FullyConnected_7/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_7/W
# Loading transformer_window_3_batch_norm/FullyConnected_7/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_7/b
# Loading transformer_window_3_batch_norm/FullyConnected_8/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_8/W
# Loading transformer_window_3_batch_norm/FullyConnected_8/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_8/b
# Loading transformer_window_3_batch_norm/BatchNormalization_2/beta:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_2/beta
# Loading transformer_window_3_batch_norm/BatchNormalization_2/gamma:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_2/gamma
# Loading transformer_window_3_batch_norm/BatchNormalization_2/moving_mean:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_2/moving_mean
# Loading transformer_window_3_batch_norm/BatchNormalization_2/moving_variance:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_2/moving_variance
# Loading transformer_window_3_batch_norm/FullyConnected_9/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_9/W
# Loading transformer_window_3_batch_norm/FullyConnected_9/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_9/b
# Loading transformer_window_3_batch_norm/FullyConnected_10/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_10/W
# Loading transformer_window_3_batch_norm/FullyConnected_10/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_10/b
# Loading transformer_window_3_batch_norm/BatchNormalization_3/beta:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_3/beta
# Loading transformer_window_3_batch_norm/BatchNormalization_3/gamma:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_3/gamma
# Loading transformer_window_3_batch_norm/BatchNormalization_3/moving_mean:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_3/moving_mean
# Loading transformer_window_3_batch_norm/BatchNormalization_3/moving_variance:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_3/moving_variance
# Loading transformer_window_3_batch_norm/FullyConnected_11/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_11/W
# Loading transformer_window_3_batch_norm/FullyConnected_11/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_11/b
# Loading transformer_window_3_batch_norm/FullyConnected_12/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_12/W
# Loading transformer_window_3_batch_norm/FullyConnected_12/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_12/b
# Loading transformer_window_3_batch_norm/FullyConnected_13/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_13/W
# Loading transformer_window_3_batch_norm/FullyConnected_13/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_13/b
# Loading transformer_window_3_batch_norm/BatchNormalization_4/beta:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_4/beta
# Loading transformer_window_3_batch_norm/BatchNormalization_4/gamma:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_4/gamma
# Loading transformer_window_3_batch_norm/BatchNormalization_4/moving_mean:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_4/moving_mean
# Loading transformer_window_3_batch_norm/BatchNormalization_4/moving_variance:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_4/moving_variance
# Loading transformer_window_3_batch_norm/FullyConnected_14/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_14/W
# Loading transformer_window_3_batch_norm/FullyConnected_14/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_14/b
# Loading transformer_window_3_batch_norm/FullyConnected_15/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_15/W
# Loading transformer_window_3_batch_norm/FullyConnected_15/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_15/b
# Loading transformer_window_3_batch_norm/BatchNormalization_5/beta:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_5/beta
# Loading transformer_window_3_batch_norm/BatchNormalization_5/gamma:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_5/gamma
# Loading transformer_window_3_batch_norm/BatchNormalization_5/moving_mean:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_5/moving_mean
# Loading transformer_window_3_batch_norm/BatchNormalization_5/moving_variance:0 from checkpoint. Name: transformer_window_3_batch_norm/BatchNormalization_5/moving_variance
# Loading transformer_window_3_batch_norm/FullyConnected_16/W:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected_16/W
# Loading transformer_window_3_batch_norm/FullyConnected_16/b:0 from checkpoint. Name: transformer_window_3_batch_norm/FullyConnected
b/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_122/b/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_122/b/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_123/W/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_123/W/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_123/W/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_123/W/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_123/b/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_123/b/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_123/b/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_123/b/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_124/W/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_124/W/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_124/W/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_124/W/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_124/b/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_124/b/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_124/b/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_124/b/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_46/beta/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_46/beta/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_46/beta/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_46/beta/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_46/gamma/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_46/gamma/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_46/gamma/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_46/gamma/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_125/W/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_125/W/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_125/W/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_125/W/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_125/b/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_125/b/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_125/b/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_125/b/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_126/W/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_126/W/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_126/W/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_126/W/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_126/b/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_126/b/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_126/b/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_126/b/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_47/beta/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_47/beta/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_47/beta/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_47/beta/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_47/gamma/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_47/gamma/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_47/gamma/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_47/gamma/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_127/W/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_127/W/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_127/W/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_127/W/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_127/b/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_127/b/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_127/b/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_127/b/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_128/W/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_128/W/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_128/W/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_128/W/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_128/b/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_128/b/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_128/b/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_128/b/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_129/W/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_129/W/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_129/W/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_129/W/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_129/b/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_129/b/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_129/b/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_129/b/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_48/beta/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_48/beta/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_48/beta/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_48/beta/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_48/gamma/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_48/gamma/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_48/gamma/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/BatchNormalization_48/gamma/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_130/W/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_130/W/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_130/W/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_130/W/Adam_1
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_130/b/Adam:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_130/b/Adam
# Loading transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_130/b/Adam_1:0 from checkpoint. Name: transformer_window_3_batch_norm/transformer_window_3_batch_norm/FullyConnected_130/b/Adam_1
# Loading transformer_window_3_batch_norm/Variable:0 from checkpoint. Name: transformer_window_3_batch_norm/Variable
# Loading transformer_window_3_batch_norm/Variable_1:0 from checkpoint. Name: transformer_window_3_batch_norm/Variable_1

# %%
# create a second dataset for testing that contains different stocks from training stocks shown above
history, abbreviation = read_stock_history(filepath='utils/datasets/stocks_history_target_2.h5')
history = history[:, :, :4]
nb_classes = len(history) + 1
print(history.shape)
print('second stock dataset', abbreviation)
testing_history = history
testing_stocks = abbreviation
target_history = history
target_stocks = abbreviation
# Out:
# (16, 1825, 4)
# second stock dataset ['FOX', 'FISV', 'EXPE', 'FAST', 'ESRX', 'DLTR', 'CTSH', 'CSCO', 'QCOM', 'PCLN', 'CELG', 'AMGN', 'WFM', 'WDC', 'NVDA', 'STX']

# %%
from environment.portfolio import PortfolioEnv, MultiActionPortfolioEnv

# %%
len(target_stocks)
# Out:
# 16

# %%
# evaluate the model with dates seen in training but from the second different stocks dataset
env = MultiActionPortfolioEnv(target_history, target_stocks, model_names[:1], steps=730, 
                              sample_start_date='2012-10-30')

observations_list, info_list, actions_list, df_performance = test_model_multiple(env, models[:1])

# %%
# evaluate the model with unseen dates from the second different stocks dataset, fixed the starting date
env = MultiActionPortfolioEnv(testing_history, testing_stocks, model_names[:1], steps=650, 
                              start_idx=num_training_time, sample_start_date='2016-12-8')

observations_list, info_list, actions_list, df_performance = test_model_multiple(env, models[:1])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25220/1126760883.py in <module>
#       3                               start_idx=num_training_time, sample_start_date='2016-12-8')
#       4
# ----> 5 observations_list, info_list, actions_list, df_performance = test_model_multiple(env, models[:1])
#       6
#
# ~\Msc\research\ddpg-rl-portfolio-management-master\ddpg-rl-portfolio-management-master\stock_trading.py in test_model_multiple(env, models)
#     341     actions_list = []
#     342     info_list = []
# --> 343     observation, info = env.reset()
#     344     done = False
#     345     while not done:
#
# ~\Msc\research\ddpg-rl-portfolio-management-master\ddpg-rl-portfolio-management-master\environment\portfolio.py in reset(self)
#     290
#     291     def reset(self):
# --> 292         return self._reset()
#     293
#     294     def _reset(self):
#
# ~\Msc\research\ddpg-rl-portfolio-management-master\ddpg-rl-portfolio-management-master\environment\portfolio.py in _reset(self)
#     422         for sim in self.sim:
#     423             sim.reset()
# --> 424         observation, ground_truth_obs = self.src.reset()
#     425         cash_observation = np.ones((1, self.window_length, observation.shape[2]))
#     426         observation = np.concatenate((cash_observation, observation), axis=0)
#
# ~\Msc\research\ddpg-rl-portfolio-management-master\ddpg-rl-portfolio-management-master\environment\portfolio.py in reset(self)
#      96             # compute index corresponding to start_date for repeatable sequence
#      97             self.idx = date_to_index(self.start_date) - self.start_idx
# ---> 98             assert self.idx >= self.window_length and self.idx <= self._data.shape[1] - self.steps, \
#      99                 'Invalid start date, must be window_length day after start date and simulation steps day before end date'
#     100         # print('Start date: {}'.format(index_to_date(self.idx)))
#
# AssertionError: Invalid start date, must be window_length day after start date and simulation steps day before end date

# %%
testing_history
# Out:
# array([[[116.04, 116.4 , 114.54, 115.15],
#         [114.32, 116.31, 114.01, 115.96],
#         [114.32, 116.31, 114.01, 115.96],
#         ...,
#         [159.26, 161.27, 159.11, 161.06],
#         [159.9 , 160.  , 154.63, 155.32],
#         [156.6 , 158.57, 156.07, 157.48]],
#
#        [[ 28.57,  29.06,  28.42,  28.85],
#         [ 28.74,  28.89,  28.47,  28.68],
#         [ 28.74,  28.89,  28.47,  28.68],
#         ...,
#         [ 60.63,  61.57,  60.35,  61.38],
#         [ 60.84,  61.25,  60.1 ,  60.21],
#         [ 60.26,  61.08,  59.77,  60.74]],
#
#        [[ 29.73,  30.09,  29.54,  29.82],
#         [ 29.72,  29.82,  29.23,  29.44],
#         [ 29.72,  29.82,  29.23,  29.44],
#         ...,
#         [ 39.54,  40.67,  39.36,  40.63],
#         [ 40.4 ,  41.05,  40.38,  40.73],
#         [ 40.76,  41.28,  40.67,  41.11]],
#
#        ...,
#
#        [[ 71.81,  72.75,  71.61,  72.3 ],
#         [ 72.25,  72.4 ,  71.44,  71.85],
#         [ 72.25,  72.4 ,  71.44,  71.85],
#         ...,
#         [103.1 , 103.2 , 101.21, 101.35],
#         [100.96, 101.  ,  99.2 ,  99.52],
#         [ 99.5 , 100.16,  98.86,  99.4 ]],
#
#        [[578.89, 585.79, 572.9 , 574.1 ],
#         [572.9 , 579.35, 568.96, 576.3 ],
#         [572.9 , 579.35, 568.96, 576.3 ],
#         ...,
#         [469.96, 478.99, 465.52, 474.09],
#         [470.48, 472.46, 459.14, 460.08],
#         [462.35, 467.86, 459.23, 466.59]],
#
#        [[ 56.52,  57.25,  56.51,  56.85],
#         [ 56.95,  57.12,  56.66,  57.1 ],
#         [ 56.95,  57.12,  56.66,  57.1 ],
#         ...,
#         [ 54.43,  54.43,  53.3 ,  53.74],
#         [ 53.52,  53.75,  52.99,  53.07],
#         [ 53.05,  53.4 ,  53.05,  53.18]]])

# %%
# evaluate the model with unseen dates from the second different stocks dataset, fixed the starting date
env = MultiActionPortfolioEnv(testing_history, testing_stocks, model_names[:1], steps=650, 
                              start_idx=num_training_time, sample_start_date='2016-12-8')
#2016-12-8
observations_list, info_list, actions_list, df_performance = test_model_multiple(env, models[:1])

# %%
import pandas as pd
actions_list = np.array(actions_list).squeeze(1)
abbreviation.insert(0,'blank')
df_actions = pd.DataFrame(actions_list, columns=abbreviation)
print('stock symbols: ', abbreviation)#[ np.argmax(actions_list[0]) -1])
maxValueIndexObj = df_actions.idxmax(axis=1)
print(' ')
print("Stock selected by the agent for each step :")
print(maxValueIndexObj)
# Out:
# stock symbols:  ['blank', 'FOX', 'FISV', 'EXPE', 'FAST', 'ESRX', 'DLTR', 'CTSH', 'CSCO', 'QCOM', 'PCLN', 'CELG', 'AMGN', 'WFM', 'WDC', 'NVDA', 'STX']
#
# Stock selected by the agent for each step :
# 0      WDC
# 1      WDC
# 2      WDC
# 3      WDC
# 4      WDC
#       ...
# 646    WDC
# 647    WDC
# 648    WDC
# 649    WDC
# 650    WDC
# Length: 651, dtype: object

# %%
df_performance = df_performance.reset_index()
maxValueIndexObj.name="stocks"
result = pd.concat([ maxValueIndexObj, df_performance.reindex(maxValueIndexObj.index)], axis=1)

print(result)
# Out:
#     stocks       date  DDPG_window_3_predictor_transformer  market_value
# 0      WDC 2016-12-10                             1.009415      0.999179
# 1      WDC 2016-12-11                             0.987598      0.988202
# 2      WDC 2016-12-12                             0.993645      0.985856
# 3      WDC 2016-12-13                             0.984431      0.979342
# 4      WDC 2016-12-14                             0.975302      0.972870
# ..     ...        ...                                  ...           ...
# 646    WDC 2018-09-17                             1.040998      0.876713
# 647    WDC 2018-09-18                             0.988879      0.868662
# 648    WDC 2018-09-19                             0.939369      0.860686
# 649    WDC 2018-09-20                             0.892339      0.852783
# 650    WDC        NaT                                  NaN           NaN
#
# [651 rows x 4 columns]

# %%
# histogram of the stocks selected by the agent
maxValueIndexObj.hist()
maxValueIndexObj.unique()
# Out:
# array(['WDC'], dtype=object)

# %%
# show the stocks selected by the agent at each step in the test period
import matplotlib.pyplot as plt
ax = plt.gca()

df_fox = result.loc[result['stocks'] == 'FOX']
df_ctsh = result.loc[result['stocks'] == 'CTSH']
df_pcln = result.loc[result['stocks'] == 'PCLN']
df_fisv = result.loc[result['stocks'] == 'FISV']
df_fox.index.name = 'idx'
df_ctsh.index.name = 'idx'
df_pcln.index.name = 'idx'
df_fisv.index.name = 'idx'


df= df_fox.reset_index()
df.plot(kind='scatter',x='idx',y='DDPG_window_3_predictor_transformer', color='blue', ax=ax, s=3, label='FOX')
df= df_fisv.reset_index()
df.plot(kind='scatter',x='idx', y='DDPG_window_3_predictor_transformer', color='red', ax=ax, s=3,label='FISV')
df= df_pcln.reset_index()
df.plot(kind='scatter',x='idx', y='DDPG_window_3_predictor_transformer', color='brown', ax=ax, s=3,label='PCLN')
df= df_ctsh.reset_index()
df.plot(kind='scatter',x='idx', y='DDPG_window_3_predictor_transformer', color='green', ax=ax, s=3,label='CTSH')
ax.legend()

plt.show()
